# %%
# importing the module 
from pytube import YouTube 
import ssl
import youtubeJsonParser as p2

ssl._create_default_https_context = ssl._create_unverified_context

links = p2.newDf['videoLink'].values.tolist()

for count, x in enumerate(links):
    print(count)
    vids = YouTube(x)
    filtered = vids.streams.filter(file_extension='mp4', type='video')

    downloadable = max(filtered, key=lambda item: 1 < item._filesize/(1024*1024) < 2)
    print(downloadable.mime_type, downloadable.itag, " ->", downloadable._filesize/(1024*1024))

    print(downloadable)
    if downloadable._filesize == 0:
        pass
    else:
        downloadable.download(output_path='downloads/')

#, filename=f'{str(count)}.mp4'

#yt = YouTube('www.youtube.com/watch?v=jhw4ILFyLZo')

#yt.streams.filter(file_extension='mp4')

#for stream in yt.streams:
 #    print(stream.mime_type, stream.itag, " ->", stream._filesize/(1024*1024), "MB")

#stream = yt.streams.get_by_itag(18)

#stream.download()
# Out:
# 0
# video/mp4 18  -> 0.0
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 1
# video/mp4 133  -> 1.62274169921875
# <Stream: itag="133" mime_type="video/mp4" res="240p" fps="25fps" vcodec="avc1.4d4015" progressive="False" type="video">
# 2
# video/mp4 160  -> 1.124837875366211
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# 3
# video/mp4 160  -> 1.9114789962768555
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# 4
# video/mp4 134  -> 1.396561622619629
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="25fps" vcodec="avc1.4d401e" progressive="False" type="video">
# 5
# video/mp4 18  -> 0.0
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="25fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 6
# video/mp4 18  -> 0.0
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="24fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 7
# video/mp4 135  -> 1.7717113494873047
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d4015" progressive="False" type="video">
# 8
# video/mp4 160  -> 1.6690969467163086
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# 9
# video/mp4 160  -> 1.9487180709838867
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# 10
# video/mp4 136  -> 1.2559213638305664
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001e" progressive="False" type="video">
# 11
# video/mp4 18  -> 9.684772491455078
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 12
# video/mp4 18  -> 18.7983455657959
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 13
# video/mp4 136  -> 1.0814580917358398
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# 14
# video/mp4 18  -> 0.0
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 15
# video/mp4 18  -> 0.8478107452392578
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 16
# video/mp4 18  -> 9.785494804382324
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 17
# video/mp4 134  -> 1.3502817153930664
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d400d" progressive="False" type="video">
# 18
# video/mp4 18  -> 3.407381057739258
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 19
# video/mp4 160  -> 1.923142433166504
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# 20
# video/mp4 18  -> 0.2698631286621094
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 21
# video/mp4 137  -> 1.7645683288574219
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# 22
# video/mp4 160  -> 1.7606182098388672
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# 23
# video/mp4 136  -> 1.1224050521850586
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="25fps" vcodec="avc1.64001e" progressive="False" type="video">
# 24
# video/mp4 135  -> 1.3088979721069336
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d4015" progressive="False" type="video">
# 25
# video/mp4 18  -> 15.777427673339844
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 26
# video/mp4 18  -> 0.0
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 27
# video/mp4 136  -> 1.556502342224121
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001e" progressive="False" type="video">
# 28
# video/mp4 18  -> 0.0
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 29
# video/mp4 18  -> 1.169926643371582
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 30
# video/mp4 18  -> 0.23566055297851562
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 31
# video/mp4 135  -> 1.5950193405151367
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d4015" progressive="False" type="video">
# 32
# video/mp4 136  -> 1.7547388076782227
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# 33
# video/mp4 135  -> 1.1822919845581055
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d4015" progressive="False" type="video">
# 34
# video/mp4 134  -> 1.3644428253173828
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d400d" progressive="False" type="video">
# 35
# video/mp4 135  -> 1.8248100280761719
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# 36
# video/mp4 18  -> 1.4726409912109375
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 37
# video/mp4 18  -> 1.8532075881958008
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 38
# video/mp4 18  -> 3.9984588623046875
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 39
# video/mp4 18  -> 8.087565422058105
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 40
# video/mp4 18  -> 1.5589284896850586
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 41
# video/mp4 18  -> 0.0
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 42
# video/mp4 134  -> 1.397252082824707
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d4015" progressive="False" type="video">
# 43
# video/mp4 18  -> 1.4690370559692383
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 44
# video/mp4 18  -> 1.3934688568115234
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 45
# video/mp4 136  -> 1.6790008544921875
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001e" progressive="False" type="video">
# 46
# video/mp4 137  -> 1.2558422088623047
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# 47
# video/mp4 18  -> 0.0
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 48
# video/mp4 18  -> 0.8059282302856445
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 49
# video/mp4 18  -> 0.0
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
